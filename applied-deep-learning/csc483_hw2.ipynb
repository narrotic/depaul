# %% [markdown]
# # Advanced Optimizers using Fashion-MNIST
#
# **Author**: Tianxiang (Adam) Gao <br>
# **Course**: CSC 383/483: Applied Deep Learning <br>
# **Description**: In this assignment, you will investigate how different optimization algorithms affect the training dynamics and final performance of a neural network on the **Fashion-MNIST** dataset using the **Keras deep learning library**. The Fashion-MNIST dataset contains 70,000 grayscale images of clothing items (such as shirts, shoes, and bags), each of size 28×28 pixels across 10 categories.
#
# You will train a simple multilayer perceptron (MLP) model using several optimizers—**SGD**, **SGD with Momentum**, **RMSprop**, and **Adam**—while keeping the network architecture, data, and initialization fixed. By comparing their learning curves and test accuracies, you will gain intuition about how optimizer choice influences convergence speed, stability, and generalization.

# %% [markdown]
# ## Setup
#
# We will first import some useful libraries:
#
# - `numpy` for numerical operations (e.g., arrays, random sampling).
# - `keras` for loading the MNIST dataset and building deep learning models.
# - `keras.layers` provides the building blocks (dense layers, convolutional layers, activation functions, etc.) to design neural networks.
# - `matplotlib` for visualizing images and plotting graphs.

# %%
import numpy as np
import keras
from keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
# ## Prepare the Data [5/5]
#
# 1. Use `keras.datasets.fashion_mnist.load_data()` to load the **Fashion-MNIST** training and testing sets.
# 2. Normalize all pixel values from integers in the range **[0, 255]** to floating-point numbers between **0 and 1**.
#
# **Note**:
# In contrast to **Assignment 1**, we **do not** use `np.expand_dims()` to add a channel dimension because MLPs operate on flattened feature vectors rather than image tensors. Similarly, we **do not** convert labels to one-hot encoding, since we will use the loss function `"sparse_categorical_crossentropy"`, which expects integer labels directly.

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0
print("x_train shape:", x_train.shape)
num_classes, input_shape = 10, x_train.shape[1:]
print("num_classes:", num_classes)
print("input_shape:", input_shape)
# Out:
# x_train shape: (60000, 28, 28)
# num_classes: 10
# input_shape: (28, 28)

# %% [markdown]
# ## Visualize the Data [5/5]
#
# 3. Randomly pick 9 images from the training set `x_train`. Display them in a 3×3 grid using Matplotlib (`plt.subplot`). For each image, show its corresponding digit label (from `y_train`) as the subplot title.

# %%
indices = np.random.choice(len(x_train), 9, replace=False)

plt.figure(figsize=(6, 6))
for i, idx in enumerate(indices):
    plt.subplot(3, 3, i + 1)
    # squeeze last channel back to 2D for grayscale display
    plt.imshow(x_train[idx].squeeze(), cmap="gray")
    # show the integer label, not one-hot
    plt.title(f"Label: {y_train[idx]}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Build the Model [30/30]
#
# 4. Implement a helper function `make_model(num_classes, input_shape)` that returns a simple two-layer MLP built by `keras.Sequential` with the following layers:
#    - Input layer: accepts images of shape `input_shape`.
#    - Flatten layer: converts each 2D image into a 1D vector.
#    - Dense layer: fully connected layer with 128 hidden units and a `"sigmoid"` activation function.
#    - Output layer: fully connected layer with `num_classes` units (one for each digit 0–9) and `"softmax"` activation.
#
# 5. Create a `base_model` using your helper function and inspect the model by calling `model.summary()` to display the network architecture, output shapes, and number of parameters in each layer.
#
# 6. Save the `initial_weights` of the `base_model` for reuse in optimizer comparisons.

# %%
def make_model(num_classes, input_shape):
    model = keras.Sequential([
        layers.Flatten(input_shape=input_shape),
        layers.Dense(128, activation='sigmoid'),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

base_model = make_model(num_classes, input_shape)
base_model.summary()

initial_weights = base_model.get_weights()
# Out:
# /Users/asadkhan/workspace/depaul/applied-deep-learning/.venv/lib/python3.13/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Define Optimizer Function [10/10]
#
# 7. To easily switch between different optimization algorithms, we will define a helper function `get_optimizer(name, lr=1e-3)` that returns the corresponding Keras optimizer object based on its name. Implement the function with the following behavior:
#    - `"sgd"`: Standard **stochastic gradient descent (SGD)**.
#    - `"momentum"`: **SGD with momentum** (momentum = 0.9).
#    - `"rmsprop"`: **RMSprop** optimizer (adaptive learning rate).
#    - `"adam"`: **Adam** optimizer (adaptive learning rate + momentum).
#    - Raise a `ValueError` if the name is unknown.

# %%
def get_optimizer(name, lr=1e-3):
    if name == "sgd":
        return keras.optimizers.SGD(learning_rate=lr)
    elif name == "momentum":
        return keras.optimizers.SGD(learning_rate=lr, momentum=0.9)
    elif name == "rmsprop":
        return keras.optimizers.RMSprop(learning_rate=lr)
    elif name == "adam":
        return keras.optimizers.Adam(learning_rate=lr)
    raise ValueError(f"Unknown optimizer: {name}")

# %% [markdown]
# ## Train and Compare Optimizers [30/30]
#
# 8. We will write a helper function `train(name, batch_size=128, epochs=20)` to train the model with a specified optimizer, then loop over several optimizers to collect their training histories for plotting:
#    - Recreate a fresh model via `make_model(...)`.
#    - **Reset** to the same `initial_weights` to ensure a fair start.
#    - Build the optimizer with `get_optimizer(name)`.
#    - `compile` with `loss="sparse_categorical_crossentropy"` and `metrics=["accuracy"]`.
#    - `fit` on `(x_train, y_train)` with `validation_data=(x_test, y_test)`.
#    - **Return** the `History` object.
#
# 9. **Compare optimizers**:
#    - Create a list `optimizers = ["sgd", "momentum", "rmsprop", "adam"]`.
#    - For each name, call `train(name, ...)` and store the returned history in a dictionary `histories[name]`.

# %%
def train(name, batch_size=128, epochs=20):
  model = make_model(num_classes, input_shape)
  model.set_weights(initial_weights)
  opt = get_optimizer(name)
  model.compile(loss="sparse_categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
  print(f"\n===Training with {name}===")
  hist = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test), verbose=1)
  return hist

# %%
optimizers = ["sgd", "momentum", "rmsprop", "adam"]
histories = {}
for opt in optimizers:
    histories[opt] = train(opt)
# Out:
# ===Training with sgd===
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.1466 - loss: 2.3540 - val_accuracy: 0.2616 - val_loss: 2.2194
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - accuracy: 0.4191 - loss: 2.1569 - val_accuracy: 0.4992 - val_loss: 2.1019
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - accuracy: 0.5394 - loss: 2.0500 - val_accuracy: 0.5694 - val_loss: 2.0019
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.5959 - loss: 1.9534 - val_accuracy: 0.6063 - val_loss: 1.9094
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.6213 - loss: 1.8640 - val_accuracy: 0.6291 - val_loss: 1.8241
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.6360 - loss: 1.7817 - val_accuracy: 0.6430 - val_loss: 1.7457
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.6499 - loss: 1.7061 - val_accuracy: 0.6515 - val_loss: 1.6739
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.6562 - loss: 1.6370 - val_accuracy: 0.6585 - val_loss: 1.6084
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.6646 - loss: 1.5738 - val_accuracy: 0.6663 - val_loss: 1.5485
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.6715 - loss: 1.5163 - val_accuracy: 0.6720 - val_loss: 1.4940
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.6761 - loss: 1.4637 - val_accuracy: 0.6787 - val_loss: 1.4442
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.6837 - loss: 1.4158 - val_accuracy: 0.6835 - val_loss: 1.3988
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.6880 - loss: 1.3719 - val_accuracy: 0.6890 - val_loss: 1.3572
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.6911 - loss: 1.3317 - val_accuracy: 0.6943 - val_loss: 1.3191
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.6974 - loss: 1.2948 - val_accuracy: 0.6978 - val_loss: 1.2840
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.7010 - loss: 1.2609 - val_accuracy: 0.6999 - val_loss: 1.2518
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7045 - loss: 1.2295 - val_accuracy: 0.7038 - val_loss: 1.2219
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.7080 - loss: 1.2005 - val_accuracy: 0.7064 - val_loss: 1.1943
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.7104 - loss: 1.1737 - val_accuracy: 0.7086 - val_loss: 1.1687
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.7132 - loss: 1.1487 - val_accuracy: 0.7115 - val_loss: 1.1449
#
# ===Training with momentum===
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 970us/step - accuracy: 0.5412 - loss: 1.8797 - val_accuracy: 0.6660 - val_loss: 1.5043
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - accuracy: 0.6947 - loss: 1.2968 - val_accuracy: 0.7067 - val_loss: 1.1493
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.7213 - loss: 1.0461 - val_accuracy: 0.7236 - val_loss: 0.9783
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.7362 - loss: 0.9140 - val_accuracy: 0.7339 - val_loss: 0.8792
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.7457 - loss: 0.8329 - val_accuracy: 0.7411 - val_loss: 0.8151
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.7532 - loss: 0.7778 - val_accuracy: 0.7508 - val_loss: 0.7700
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7602 - loss: 0.7375 - val_accuracy: 0.7544 - val_loss: 0.7360
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.7662 - loss: 0.7065 - val_accuracy: 0.7587 - val_loss: 0.7089
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.7713 - loss: 0.6815 - val_accuracy: 0.7626 - val_loss: 0.6869
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.7768 - loss: 0.6607 - val_accuracy: 0.7685 - val_loss: 0.6681
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.7824 - loss: 0.6428 - val_accuracy: 0.7724 - val_loss: 0.6529
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 0.7856 - loss: 0.6275 - val_accuracy: 0.7781 - val_loss: 0.6384
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.7904 - loss: 0.6138 - val_accuracy: 0.7821 - val_loss: 0.6259
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.7939 - loss: 0.6016 - val_accuracy: 0.7855 - val_loss: 0.6154
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.7980 - loss: 0.5908 - val_accuracy: 0.7913 - val_loss: 0.6050
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.8005 - loss: 0.5808 - val_accuracy: 0.7933 - val_loss: 0.5965
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - accuracy: 0.8033 - loss: 0.5718 - val_accuracy: 0.7956 - val_loss: 0.5887
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.8058 - loss: 0.5636 - val_accuracy: 0.7981 - val_loss: 0.5805
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.8079 - loss: 0.5560 - val_accuracy: 0.7998 - val_loss: 0.5741
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.8108 - loss: 0.5491 - val_accuracy: 0.8025 - val_loss: 0.5684
#
# ===Training with rmsprop===
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7858 - loss: 0.6561 - val_accuracy: 0.8140 - val_loss: 0.5116
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.8425 - loss: 0.4427 - val_accuracy: 0.8419 - val_loss: 0.4432
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - accuracy: 0.8560 - loss: 0.4043 - val_accuracy: 0.8467 - val_loss: 0.4320
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 0.8637 - loss: 0.3812 - val_accuracy: 0.8541 - val_loss: 0.4060
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.8693 - loss: 0.3640 - val_accuracy: 0.8576 - val_loss: 0.3960
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.8734 - loss: 0.3501 - val_accuracy: 0.8607 - val_loss: 0.3837
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 0.8782 - loss: 0.3383 - val_accuracy: 0.8595 - val_loss: 0.3863
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - accuracy: 0.8817 - loss: 0.3279 - val_accuracy: 0.8672 - val_loss: 0.3726
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8842 - loss: 0.3177 - val_accuracy: 0.8696 - val_loss: 0.3664
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.8875 - loss: 0.3095 - val_accuracy: 0.8689 - val_loss: 0.3617
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8900 - loss: 0.3020 - val_accuracy: 0.8655 - val_loss: 0.3663
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8912 - loss: 0.2953 - val_accuracy: 0.8758 - val_loss: 0.3499
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - accuracy: 0.8953 - loss: 0.2884 - val_accuracy: 0.8726 - val_loss: 0.3553
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.8972 - loss: 0.2818 - val_accuracy: 0.8772 - val_loss: 0.3390
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.8987 - loss: 0.2764 - val_accuracy: 0.8780 - val_loss: 0.3421
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.9001 - loss: 0.2710 - val_accuracy: 0.8780 - val_loss: 0.3369
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.9020 - loss: 0.2655 - val_accuracy: 0.8771 - val_loss: 0.3410
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.9032 - loss: 0.2613 - val_accuracy: 0.8782 - val_loss: 0.3407
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.9055 - loss: 0.2561 - val_accuracy: 0.8787 - val_loss: 0.3334
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - accuracy: 0.9069 - loss: 0.2521 - val_accuracy: 0.8804 - val_loss: 0.3329
#
# ===Training with adam===
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7794 - loss: 0.6868 - val_accuracy: 0.8289 - val_loss: 0.4984
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.8444 - loss: 0.4426 - val_accuracy: 0.8432 - val_loss: 0.4440
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - accuracy: 0.8593 - loss: 0.3969 - val_accuracy: 0.8507 - val_loss: 0.4211
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - accuracy: 0.8673 - loss: 0.3737 - val_accuracy: 0.8572 - val_loss: 0.4029
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 0.8730 - loss: 0.3548 - val_accuracy: 0.8599 - val_loss: 0.3922
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - accuracy: 0.8781 - loss: 0.3404 - val_accuracy: 0.8631 - val_loss: 0.3848
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.8836 - loss: 0.3263 - val_accuracy: 0.8679 - val_loss: 0.3723
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.8860 - loss: 0.3159 - val_accuracy: 0.8704 - val_loss: 0.3607
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - accuracy: 0.8900 - loss: 0.3061 - val_accuracy: 0.8717 - val_loss: 0.3562
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.8923 - loss: 0.2977 - val_accuracy: 0.8718 - val_loss: 0.3532
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.8949 - loss: 0.2885 - val_accuracy: 0.8726 - val_loss: 0.3513
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - accuracy: 0.8974 - loss: 0.2817 - val_accuracy: 0.8767 - val_loss: 0.3402
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - accuracy: 0.8997 - loss: 0.2750 - val_accuracy: 0.8756 - val_loss: 0.3424
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.9024 - loss: 0.2689 - val_accuracy: 0.8716 - val_loss: 0.3500
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - accuracy: 0.9056 - loss: 0.2615 - val_accuracy: 0.8760 - val_loss: 0.3402
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.9075 - loss: 0.2556 - val_accuracy: 0.8842 - val_loss: 0.3306
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 0.9097 - loss: 0.2489 - val_accuracy: 0.8830 - val_loss: 0.3313
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - accuracy: 0.9107 - loss: 0.2452 - val_accuracy: 0.8836 - val_loss: 0.3299
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.9125 - loss: 0.2404 - val_accuracy: 0.8823 - val_loss: 0.3290
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.9149 - loss: 0.2339 - val_accuracy: 0.8856 - val_loss: 0.3255

# %% [markdown]
# ## Plot Training and Test Loss [10/10]
#
# 10. We will now visualize the **training and test loss curves** for all optimizers on a single plot. Write a function `plot_histories(histories, optimizers, log_scale=False)` that:
#
# - Creates a new figure using `plt.figure(figsize=(8,5))`.
# - Iterates through each optimizer in the list.
# - Plots both **training loss** (solid line) and **test loss** (dashed line) for the same color.
# - Adds axis labels, title, legend, and grid lines.
# - Optionally uses a logarithmic y-axis if `log_scale=True` (use `plt.yscale("log")`).
#
# 11. Call the function twice:
#
# - Once with the default linear scale.
# - Once with `log_scale=True` to observe convergence differences in early epochs.

# %%
def plot_histories(histories, optimizers, log_scale=False):
    plt.figure(figsize=(8, 5))
    colors = plt.cm.tab10.colors

    for i, opt in enumerate(optimizers):
        color = colors[i % len(colors)]
        history = histories[opt].history
        # Plot training loss (solid line)
        plt.plot(history['loss'], color=color, linestyle='-', label=f"{opt} Train")
        # Plot test/validation loss (dashed line)
        plt.plot(history['val_loss'], color=color, linestyle='--', label=f"{opt} Test")

    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training vs Validation Loss (Different Optimizers)")
    plt.legend()
    plt.grid(True, which="both", ls=":")
    if log_scale:
        plt.yscale("log")
        plt.ylabel("Loss (log scale)")
    plt.show()


# Example calls
plot_histories(histories, optimizers, log_scale=False)  # linear scale
plot_histories(histories, optimizers, log_scale=True)  # log scale

# %% [markdown]
# ## Interpretation and Discussion [10/10]
#
# Write a short reflection (3–5 sentences) interpreting your results.
#
# **Note**:
# Your explanation should focus on what you observe from the **training and validation curves** rather than theoretical definitions.
# Be concise but specific — mention patterns you can clearly see in your plots and test results.

# %% [markdown]
# From the training and validation loss curves, we can see that all optimizers reduce the training loss steadily, but some converge faster than others. For example, Adam and RMSprop reach lower losses earlier, while SGD and Momentum decrease more gradually. The validation loss generally follows the training loss, indicating that the models are learning effectively without severe overfitting, though some minor fluctuations appear in later epochs. Using the log-scale plot highlights early differences in convergence speed, showing that adaptive optimizers adapt faster to the loss landscape. Overall, Adam and RMSprop provide the quickest and most stable convergence on this dataset.
